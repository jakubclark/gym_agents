# %%
from gym_agents.util import generate_report
# Out:
# Using TensorFlow backend.

# %%
agent_id = 'DQNAgent'
env_id = 'CustomMountainCar-v0'
independent_variable = 'controlled'

# %%
generate_report(agent_id, env_id, independent_variable, 0)
# Out:
# Report for the Independent Variable:controlled
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -83.34843837326076
# Average reward during testing: -22.375962563860476
# Average num of steps during training: 159.8816
# Average num of steps during testing: 131.23
# Number of training games played: 625
# Number of testing games played: 100
# The saved model had a mean reward of: -21.095240322399068
