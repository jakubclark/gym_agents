# %%
from gym_agents.util import generate_report
# Out:
# Using TensorFlow backend.

# %%
agent_id = 'DQNAgent'
env_id = 'CustomMountainCar-v0'
independent_variable = 'epsilon_decay'

# %%
generate_report(agent_id, env_id, independent_variable, 0)
# Out:
# Report for the Independent Variable:epsilon_decay
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.9,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009697737297875247,
#   'epsilon_decay': 0.9,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -92.03913661882027
# Average reward during testing: -36.00878743621442
# Average num of steps during training: 186.4570895522388
# Average num of steps during testing: 158.52
# Number of training games played: 536
# Number of testing games played: 100
# The saved model had a mean reward of: -39.83183018332872

# %%
generate_report(agent_id, env_id, independent_variable, 1)
# Out:
# Report for the Independent Variable:epsilon_decay
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -83.37142792513511
# Average reward during testing: -35.55316187813499
# Average num of steps during training: 177.80249110320284
# Average num of steps during testing: 163.76
# Number of training games played: 562
# Number of testing games played: 100
# The saved model had a mean reward of: -23.519359947214227

# %%
generate_report(agent_id, env_id, independent_variable, 2)
# Out:
# Report for the Independent Variable:epsilon_decay
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009998671593271896,
#   'epsilon_decay': 0.999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -79.64419630269842
# Average reward during testing: -23.849591540911412
# Average num of steps during training: 156.70643642072213
# Average num of steps during testing: 137.72
# Number of training games played: 637
# Number of testing games played: 100
# The saved model had a mean reward of: -18.194553011298673
