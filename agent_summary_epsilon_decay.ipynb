# %%
from gym_agents.util import generate_report
# Out:
# Using TensorFlow backend.

# %%
agent_id = 'DQNAgent'
env_id = 'CustomMountainCar-v0'
independent_variable = 'epsilon_decay'

# %%
generate_report(agent_id, env_id, independent_variable, 0)
# Out:
# Report for the Independent Variable:epsilon_decay
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.9,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009697737297875247,
#   'epsilon_decay': 0.9,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -92.52792864784192
# Average reward during testing: -26.154883842446644
# Average num of steps during training: 172.98269896193773
# Average num of steps during testing: 136.96
# Number of training games played: 578
# Number of testing games played: 100
# The saved model had a mean reward of: 2.2761373138394427

# %%
generate_report(agent_id, env_id, independent_variable, 1)
# Out:
# Report for the Independent Variable:epsilon_decay
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009998671593271896,
#   'epsilon_decay': 0.999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -113.62017308105005
# Average reward during testing: -59.32542134566364
# Average num of steps during training: 183.68014705882354
# Average num of steps during testing: 185.03
# Number of training games played: 544
# Number of testing games played: 100
# The saved model had a mean reward of: -44.152742492506995

# %%
generate_report(agent_id, env_id, independent_variable, 2)
# Out:
# Report for the Independent Variable:epsilon_decay
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.9999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.08207473795634762,
#   'epsilon_decay': 0.9999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -154.77814608123805
# Average reward during testing: -33.55429588344922
# Average num of steps during training: 196.32809430255404
# Average num of steps during testing: 168.01
# Number of training games played: 509
# Number of testing games played: 100
# The saved model had a mean reward of: -57.63888481082344
