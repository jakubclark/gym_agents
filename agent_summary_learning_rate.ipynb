# %%
from gym_agents.util import generate_report
# Out:
# Using TensorFlow backend.

# %%
agent_id = 'DQNAgent'
env_id = 'CustomMountainCar-v0'
independent_variable = 'learning_rate'

# %%
generate_report(agent_id, env_id, independent_variable, 0)
# Out:
# Report for the Independent Variable:learning_rate
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.01,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.01,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -87.14033124883673
# Average reward during testing: -21.69978716118048
# Average num of steps during training: 177.50088809946715
# Average num of steps during testing: 139.85
# Number of training games played: 563
# Number of testing games played: 100
# The saved model had a mean reward of: -22.616919327368475

# %%
generate_report(agent_id, env_id, independent_variable, 1)
# Out:
# Report for the Independent Variable:learning_rate
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.0001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.0001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -194.6430145471831
# Average reward during testing: -186.0436696146517
# Average num of steps during training: 200.0
# Average num of steps during testing: 200.0
# Number of training games played: 500
# Number of testing games played: 100
# The saved model had a mean reward of: -174.2046459776401

# %%
generate_report(agent_id, env_id, independent_variable, 2)
# Out:
# Report for the Independent Variable:learning_rate
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 1e-05,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 1e-05,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -198.56616652680364
# Average reward during testing: -200.0
# Average num of steps during training: 200.0
# Average num of steps during testing: 200.0
# Number of training games played: 500
# Number of testing games played: 100
# The saved model had a mean reward of: -185.0349979065193
