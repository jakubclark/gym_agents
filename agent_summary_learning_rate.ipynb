# %%
from gym_agents.util import generate_report
# Out:
# Using TensorFlow backend.

# %%
agent_id = 'DQNAgent'
env_id = 'CustomMountainCar-v0'
independent_variable = 'learning_rate'

# %%
generate_report(agent_id, env_id, independent_variable, 0)
# Out:
# Report for the Independent Variable:learning_rate
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.01,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.01,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -111.22477525340618
# Average reward during testing: -28.78156384838518
# Average num of steps during training: 191.8637236084453
# Average num of steps during testing: 158.97
# Number of training games played: 521
# Number of testing games played: 100
# The saved model had a mean reward of: -10.442286973849052

# %%
generate_report(agent_id, env_id, independent_variable, 1)
# Out:
# Report for the Independent Variable:learning_rate
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -82.65807227906316
# Average reward during testing: -53.70497095851765
# Average num of steps during training: 181.79090909090908
# Average num of steps during testing: 200.0
# Number of training games played: 550
# Number of testing games played: 100
# The saved model had a mean reward of: -33.435922297173505

# %%
generate_report(agent_id, env_id, independent_variable, 2)
# Out:
# Report for the Independent Variable:learning_rate
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.0001,
#   'num_layers': 1}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.0001,
#   'num_layers': 1}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -177.44654748838713
# Average reward during testing: -62.429026849790574
# Average num of steps during training: 197.5098814229249
# Average num of steps during testing: 162.79
# Number of training games played: 506
# Number of testing games played: 100
# The saved model had a mean reward of: -58.591830155361926
