# %%
from gym_agents.util import generate_report
# Out:
# Using TensorFlow backend.

# %%
agent_id = 'DQNAgent'
env_id = 'CustomMountainCar-v0'
independent_variable = 'num_layers'

# %%
generate_report(agent_id, env_id, independent_variable, 0)
# Out:
# Report for the Independent Variable:num_layers
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 0}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 0}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -83.36127811136691
# Average reward during testing: -92.86924420470305
# Average num of steps during training: 177.8185053380783
# Average num of steps during testing: 193.0
# Number of training games played: 562
# Number of testing games played: 100
# The saved model had a mean reward of: -18.333647396603126

# %%
generate_report(agent_id, env_id, independent_variable, 1)
# Out:
# Report for the Independent Variable:num_layers
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 2}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 2}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -68.62006728875852
# Average reward during testing: -33.56210576034243
# Average num of steps during training: 148.5081723625557
# Average num of steps during testing: 136.05
# Number of training games played: 673
# Number of testing games played: 100
# The saved model had a mean reward of: -24.370477690992637

# %%
generate_report(agent_id, env_id, independent_variable, 2)
# Out:
# Report for the Independent Variable:num_layers
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 3}
# Final agent config:
# { 'epsilon': 0.009920974201040588,
#   'epsilon_decay': 0.99,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.001,
#   'num_layers': 3}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -111.8699103169108
# Average reward during testing: -118.86192655340585
# Average num of steps during training: 187.49155722326455
# Average num of steps during testing: 176.69
# Number of training games played: 533
# Number of testing games played: 100
# The saved model had a mean reward of: -54.9605298941601
