# %%
from gym_agents.util import generate_report
# Out:
# Using TensorFlow backend.

# %%
agent_id = 'DQNAgent'
env_id = 'CustomMountainCar-v0'
independent_variable = 'best_performing'

# %%
generate_report(agent_id, env_id, independent_variable, 0)
# Out:
# Report for the Independent Variable:best_performing
# Initial agent config:
# { 'epsilon': 1.0,
#   'epsilon_decay': 0.999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.01,
#   'num_layers': 2}
# Final agent config:
# { 'epsilon': 0.009998671593271896,
#   'epsilon_decay': 0.999,
#   'epsilon_min': 0.01,
#   'gamma': 0.95,
#   'learning_rate': 0.01,
#   'num_layers': 2}
# Train Episode Plots:
# Test Episode Plots:
# Agent & Model During Training:
# Saved Mean over time:
# Report for a single game, using the trained agent:
# Policy the agent uses when playing:
# Average reward during training: -88.46931501758176
# Average reward during testing: -79.04522526524259
# Average num of steps during training: 185.65799256505576
# Average num of steps during testing: 200.0
# Number of training games played: 538
# Number of testing games played: 100
# The saved model had a mean reward of: -19.552544883737923
